# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-73cdecd48ecd> in <module>
#      10 d.set_index("datetime",inplace=True)
#      11
# ---> 12 d2 = d[["NASDAQ_Canadian_Chix_A","CDF_feeds_A",3,4,5]]
#      13
#      14 #d2.head()
#
# ~/miniconda3/envs/6.86x/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/miniconda3/envs/6.86x/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/miniconda3/envs/6.86x/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: '[3, 4, 5] not in index'

# %%
# NASDAQ_Canadian_Chix_A
d = pd.read_csv("./data/TripleWitching-2024-05-06 15_56_54.csv",header=1)    # index_col=0, parse_dates=True
d['datetime'] = pd.to_datetime(d['Time'], unit='ms')
d.set_index("datetime",inplace=True)

# d2 = d[["NASDAQ_Canadian_Chix_A","CDF_feeds_A"]]
d2 = d.iloc[:,1:20]
d2.head()
#d2.info()
#d2.index
# Out:
#                      Aeqnitch__Aequitas_NEO_A  BATS_BYX_Feeds_A  \
# datetime
# 2024-02-06 14:00:00                   70754.4           56736.0
# 2024-02-06 15:00:00                  102161.6           81391.2
# 2024-02-06 16:00:00                   61199.2           64275.2
# 2024-02-06 17:00:00                   65658.4           65716.0
# 2024-02-06 18:00:00                   81238.4           65848.8
#
#                      BATS_BZX_Feeds_A  CBBO_Feeds__Best_Bid_Offer_A  \
# datetime
# 2024-02-06 14:00:00          210924.0                       93559.2
# 2024-02-06 15:00:00          274977.6                      131626.4
# 2024-02-06 16:00:00          192967.2                       86469.6
# 2024-02-06 17:00:00          209691.2                       95500.8
# 2024-02-06 18:00:00          273037.6                      116062.4
#
#                      CBOE__BATSEDGA_A  CBOE__BATS_EDGX_A  CDF_feeds_A  \
# datetime
# 2024-02-06 14:00:00           50884.0           184172.8     249432.0
# 2024-02-06 15:00:00           70194.4           191275.2     333477.6
# 2024-02-06 16:00:00           49261.6           129784.0     218575.2
# 2024-02-06 17:00:00           63262.4           150103.2     238604.0
# 2024-02-06 18:00:00           65192.0           149772.0     294739.2
#
#                      CQS_Pillar_feeds_A  CSEMC_Feed__Canadian_Securities_Ex_A  \
# datetime
# 2024-02-06 14:00:00                19.2                               19942.4
# 2024-02-06 15:00:00                19.2                               28259.2
# 2024-02-06 16:00:00                19.2                               15998.4
# 2024-02-06 17:00:00                19.2                               19280.8
# 2024-02-06 18:00:00                19.2                               29918.4
#
#                      CTS_Pillard_Feeds_A  Canadian_feeds_A  FINRA_tdds_A  \
# datetime
# 2024-02-06 14:00:00                 20.8          120756.8         123.2
# 2024-02-06 15:00:00                 20.8          188412.8         296.8
# 2024-02-06 16:00:00                 20.8          116253.6        1089.6
# 2024-02-06 17:00:00                 20.8          132528.0         373.6
# 2024-02-06 18:00:00                 20.8          180735.2         318.4
#
#                      IEX_Feeds__TOPS_and_DEEP_A  Intelligent_Cross_ASPEN_A  \
# datetime
# 2024-02-06 14:00:00                    159774.4                    48000.0
# 2024-02-06 15:00:00                    176316.0                    66795.2
# 2024-02-06 16:00:00                    145490.4                    43113.6
# 2024-02-06 17:00:00                    152764.8                    49278.4
# 2024-02-06 18:00:00                    164926.4                    79268.8
#
#                      MEMX_Feeds_A  MIAX_Feeds_A  \
# datetime
# 2024-02-06 14:00:00      122699.2       77916.0
# 2024-02-06 15:00:00      147449.6      106680.8
# 2024-02-06 16:00:00      102920.8       66000.0
# 2024-02-06 17:00:00      109118.4       69724.0
# 2024-02-06 18:00:00      126773.6       70733.6
#
#                      NASDAQ_Canadian_CXD_Purestream_A  NASDAQ_Canadian_Chix_A  \
# datetime
# 2024-02-06 14:00:00                              55.2                 34291.2
# 2024-02-06 15:00:00                              65.6                 37201.6
# 2024-02-06 16:00:00                              80.0                 22200.0
# 2024-02-06 17:00:00                              63.2                 26984.0
# 2024-02-06 18:00:00                              60.8                 36220.8
#
#                      NEW_CQS_Pillar_feeds_A
# datetime
# 2024-02-06 14:00:00                644388.0
# 2024-02-06 15:00:00                811772.0
# 2024-02-06 16:00:00                585492.8
# 2024-02-06 17:00:00                705765.6
# 2024-02-06 18:00:00                667779.2

# %%
#dh.plot.bar(title="test", figsize=(30,8))

#plt = dh.loc['2024-3-10':'2024-3-20'].plot(kind="bar")
#plt.figure(figsize = (30,8)) 
#plt.tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False) 

dh = d2['2024-03-1 06:00:00':'2024-05-16 06:00:00']  #.resample("10min").sum()
#print(dh)
fig = px.bar(dh)    # .loc['2024-03-01':'2024-03-3']
fig.show()
